# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data= pd.read_csv('/content/drive/MyDrive/ml/mobile_price_pred.csv')
data.head()
# Out:
#    battery_power bluetooth  clock_speed dual_sim  front_camera_mpixels has_4g  \
# 0            842        No          2.2       No                     1     No
# 1           1021       Yes          0.5      Yes                     0    Yes
# 2            563       Yes          0.5      Yes                     2    Yes
# 3            615       Yes          2.5       No                     0     No
# 4           1821       Yes          1.2       No                    13    Yes
#
#    int_memory  m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  \
# 0           7    0.6        188        2  ...         20       756  2549
# 1          53    0.7        136        3  ...        905      1988  2631
# 2          41    0.9        145        5  ...       1263      1716  2603
# 3          10    0.8        131        6  ...       1216      1786  2769
# 4          44    0.6        141        2  ...       1208      1212  1411
#
# ...

# %%
data['price_range'].head(10)
# Out:
# 0       Medium Cost
# 1         High Cost
# 2         High Cost
# 3         High Cost
# 4       Medium Cost
# 5       Medium Cost
# 6    Very High Cost
# 7          Low Cost
# 8          Low Cost
# 9          Low Cost
# Name: price_range, dtype: object

# %%
data.isnull().sum()
# Out:
# battery_power           0
# bluetooth               0
# clock_speed             0
# dual_sim                0
# front_camera_mpixels    0
# has_4g                  0
# int_memory              0
# m_dep                   0
# mobile_wt               0
# n_cores                 0
# pc                      0
# px_height               0
# px_width                0
# ram                     0
# sc_h                    0
# sc_w                    0
# talk_time               0
# has_3g                  0
# touch_screen            0
# wifi                    0
# price_range             0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

plt.bar(data['price_range'],data['ram'])
plt.xlabel('price_range')
plt.ylabel('ram')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

plt.bar(data['price_range'],data['battery_power'])
plt.xlabel('price_range')
plt.ylabel('battery_power')
plt.show()

# %%
plt.pie(data['price_range'].value_counts(),labels=['Low Cost','Medium Cost','High Cost','Very High Cost'],autopct='%1.1f%%')
plt.show()

# %%
plt.pie(data['dual_sim'].value_counts(),labels=['has_dual sim','no dual sim'],autopct='%1.1f%%')
plt.show()

# %%
plt.pie(data['touch_screen'].value_counts(),labels=['has_touch_screen','no touch_screen'],autopct='%1.1f%%')
plt.show()

# %%
plt.pie(data['wifi'].value_counts(),labels=['has_wifi','no wifi'],autopct='%1.1f%%')
plt.show()

# %%
plt.pie(data['has_3g'].value_counts(),labels=['has_three_g','no three_g'],autopct='%1.1f%%')
plt.show()

# %%
data.head()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
encode={'Medium Cost':1,'High Cost':2,'Low Cost':0,'Very High Cost':3}
data['price_range']=data['price_range'].map(encode)

# %%
labels=data.select_dtypes('object').columns
for label in labels:
  data[label]=le.fit_transform(data[label])

# %%
data
# Out:
#       battery_power  bluetooth  clock_speed  dual_sim  front_camera_mpixels  \
# 0               842          0          2.2         0                     1
# 1              1021          1          0.5         1                     0
# 2               563          1          0.5         1                     2
# 3               615          1          2.5         0                     0
# 4              1821          1          1.2         0                    13
# ...             ...        ...          ...       ...                   ...
# 1995            794          1          0.5         1                     0
# 1996           1965          1          2.6         1                     0
# 1997           1911          0          0.9         1                     1
# 1998           1512          0          0.9         0                     4
# 1999            510          1          2.0         1                     5
#
# ...

# %%
data.columns
# Out:
# Index(['battery_power', 'bluetooth', 'clock_speed', 'dual_sim',
#        'front_camera_mpixels', 'has_4g', 'int_memory', 'm_dep', 'mobile_wt',
#        'n_cores', 'pc', 'px_height', 'px_width', 'ram', 'sc_h', 'sc_w',
#        'talk_time', 'has_3g', 'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
plt.figure(figsize=(15,10))
corr_matrix = data.corr()
sns.heatmap(corr_matrix,cmap="coolwarm", annot=True, fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
# !pip install xgboost
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier,ExtraTreesClassifier,BaggingClassifier,StackingClassifier

scaler=StandardScaler()

x_train,x_test,y_train,y_test=train_test_split(data.drop('price_range',axis=1),data['price_range'],test_size=0.2,random_state=42)

X_train=scaler.fit_transform(x_train)
X_test=scaler.transform(x_test)

models=[LogisticRegression(),RandomForestClassifier(),KNeighborsClassifier(),SVC(),GaussianNB(),DecisionTreeClassifier(),AdaBoostClassifier(),GradientBoostingClassifier(),ExtraTreesClassifier(),BaggingClassifier(),XGBClassifier()]
for model in models:
  model.fit(X_train,y_train)
  y_pred=model.predict(X_test)


  print(model,"-",end="")
  print('Accuracy:',accuracy_score(y_test,y_pred))
  print(classification_report(y_test,y_pred))
  print(confusion_matrix(y_test,y_pred))
  print("------------------------------------------------------------------")
  print(               'b_power', 'blt', 'clc_sp', 'd_sim','f_c_pixels', 'has_4g', 'int_memory', 'm_dep', 'mobile_wt','n_cores', 'pc', 'px_height', 'px_width', 'ram', 'sc_h', 'sc_w','talk_time', 'has_3g', 'touch_screen', 'wifi')
  sc=scaler.transform([[ 5000,    0,	    2.2,     	0,	    1	,            0,       	7,	         0.6,	      188,       2	,      2,   	20,        	756,        4000,	 9	,    7,	   19,	         0,       0,            	1	]])
  Y_predict=model.predict(sc)
  print(Y_predict)
# Out:
# ...
# LogisticRegression() -Accuracy: 0.975
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98       105
#            1       0.94      1.00      0.97        91
#            2       0.99      0.95      0.97        92
#            3       0.97      0.99      0.98       112
#
#     accuracy                           0.97       400
#    macro avg       0.98      0.97      0.97       400
# weighted avg       0.98      0.97      0.98       400
#
# [[101   4   0   0]
#  [  0  91   0   0]
#  [  0   2  87   3]
#  [  0   0   1 111]]
# ------------------------------------------------------------------
# b_power blt clc_sp d_sim f_c_pixels has_4g int_memory m_dep mobile_wt n_cores pc px_height px_width ram sc_h sc_w talk_time has_3g touch_screen wifi
# [3]
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ...

# %%
# !pip install scikit-learn==1.5.2
import sys
import sklearn
old_sklearn_tags = sklearn.utils._tags.get_tags
def get_tags(estimator):
    try:
        return old_sklearn_tags(estimator)
    except AttributeError:
        return {}
sklearn.utils._tags.get_tags = get_tags
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 82.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.0
#     Uninstalling scikit-learn-1.6.0:
#       Successfully uninstalled scikit-learn-1.6.0
# ...

# %%
from sklearn.model_selection import KFold,cross_val_score,cross_val_predict


models=[LogisticRegression(),RandomForestClassifier(),KNeighborsClassifier(),SVC(),GaussianNB(),DecisionTreeClassifier(),AdaBoostClassifier(),GradientBoostingClassifier(),ExtraTreesClassifier(),BaggingClassifier(),XGBClassifier()]
for model in models:
  model.fit(X_train,y_train)
  kf = KFold(n_splits=10, shuffle=True, random_state=42)

  scores = cross_val_score(model, X_train, y_train, cv=kf)
  print(model,"-",end="")
  print('score:',scores.mean()*100)

  y_pred_lda=cross_val_predict(model,X_test,y_test,cv=kf)
  print(model,"-",end="")
  print('Accuracy:',accuracy_score(y_test,y_pred_lda)*100)
  print(classification_report(y_test,y_pred_lda))
  print(confusion_matrix(y_test,y_pred_lda))
  print("------------------------------------------------------------------")
# Out:
# LogisticRegression() -score: 95.56249999999999
# LogisticRegression() -Accuracy: 89.0
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95       105
#            1       0.84      0.81      0.83        91
#            2       0.82      0.80      0.81        92
#            3       0.93      0.96      0.94       112
#
#     accuracy                           0.89       400
#    macro avg       0.88      0.88      0.88       400
# weighted avg       0.89      0.89      0.89       400
#
# [[101   4   0   0]
#  [  6  74  11   0]
#  [  0  10  74   8]
#  [  0   0   5 107]]
# ------------------------------------------------------------------
# RandomForestClassifier() -score: 87.1875
# RandomForestClassifier() -Accuracy: 82.25
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92       105
#            1       0.74      0.74      0.74        91
# ...

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis




lda= LinearDiscriminantAnalysis(n_components=3)

X_train_lda=lda.fit_transform(X_train,y_train)
X_test_lda=lda.transform(X_test)

models=[LogisticRegression(),RandomForestClassifier(),KNeighborsClassifier(),SVC(),GaussianNB(),DecisionTreeClassifier(),AdaBoostClassifier(),GradientBoostingClassifier(),ExtraTreesClassifier(),BaggingClassifier(),XGBClassifier()]
for model in models:
  model.fit(X_train_lda,y_train)
  y_pred_lda=model.predict(X_test_lda)

  print(model,"-",end="")
  print('Accuracy:',accuracy_score(y_test,y_pred_lda))
  print(classification_report(y_test,y_pred_lda))
  print(confusion_matrix(y_test,y_pred_lda))
  print("------------------------------------------------------------------")
# Out:
# LogisticRegression() -Accuracy: 0.9675
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99       105
#            1       0.96      0.99      0.97        91
#            2       0.94      0.96      0.95        92
#            3       0.97      0.96      0.96       112
#
#     accuracy                           0.97       400
#    macro avg       0.97      0.97      0.97       400
# weighted avg       0.97      0.97      0.97       400
#
# [[102   3   0   0]
#  [  0  90   1   0]
#  [  0   1  88   3]
#  [  0   0   5 107]]
# ------------------------------------------------------------------
# RandomForestClassifier() -Accuracy: 0.965
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       105
#            1       0.96      0.98      0.97        91
#            2       0.95      0.95      0.95        92
#            3       0.96      0.96      0.96       112
#
# ...

# %%
from sklearn.model_selection import KFold,cross_val_score,cross_val_predict


for model in models:
  model.fit(X_train_lda,y_train)
  kf = KFold(n_splits=10, shuffle=True, random_state=42)

  scores = cross_val_score(model, X_train_lda, y_train, cv=kf)
  print(model,"-",end="")
  print('score:',scores.mean()*100)

  y_pred_lda=cross_val_predict(model,X_test_lda,y_test,cv=kf)
  print(model,"-",end="")
  print('Accuracy:',accuracy_score(y_test,y_pred_lda)*100)
  print(classification_report(y_test,y_pred_lda))
  print(confusion_matrix(y_test,y_pred_lda))
  print("------------------------------------------------------------------")
# Out:
# LogisticRegression() -score: 96.76101928374656
# LogisticRegression() -Accuracy: 96.68874172185431
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97        88
#            1       0.94      0.92      0.93        71
#            2       0.96      0.97      0.96        66
#            3       1.00      1.00      1.00        77
#
#     accuracy                           0.97       302
#    macro avg       0.97      0.97      0.97       302
# weighted avg       0.97      0.97      0.97       302
#
# [[86  2  0  0]
#  [ 3 65  3  0]
#  [ 0  2 64  0]
#  [ 0  0  0 77]]
# ------------------------------------------------------------------
# RandomForestClassifier() -score: 95.26377410468318
# RandomForestClassifier() -Accuracy: 95.36423841059603
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96        88
#            1       0.89      0.92      0.90        71
# ...

# %%
from sklearn.model_selection import GridSearchCV

param_grid_rf = {
    'n_estimators': [100, 200, 300],  # number of trees
    'max_depth': [None, 5, 10],  # maximum depth of each tree
    'min_samples_split': [2, 5, 10]  # minimum samples required to split an internal node
}

param_grid1_dt = {
    'max_depth': [None, 5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 5, 10],
    'criterion': ['gini', 'entropy']
}
param_grid2_lr = {
    'C': [0.001, 0.01, 0.1, 1, 10],  # Inverse of regularization strength
    'penalty': ['l1', 'l2'],         # Regularization type
    'solver': ['liblinear', 'saga'], # Optimization algorithm
    'max_iter': [100, 200,300]
}
models1=[RandomForestClassifier(),DecisionTreeClassifier(),LogisticRegression()]
param_grid=[param_grid_rf,param_grid1_dt,param_grid2_lr]
for model,param in zip(models1,param_grid):
  grid_search=GridSearchCV(model,param,cv=5)
  grid_search.fit(X_train_lda,y_train)
  best_model=grid_search.best_estimator_
  y_pred=best_model.predict(X_test_lda)
  print(model,"-",end="")

  print(classification_report(y_test,y_pred))
  print(confusion_matrix(y_test,y_pred))
  print('Accuracy:',accuracy_score(y_test,y_pred))

# %%
import numpy as np
knn_param_grid = {
    "n_neighbors": np.linspace(2, 20, 12, dtype=int).tolist(),
    "weights": ["uniform", "distance"],
    "metric": ["euclidean", "manhattan", "minkowski"],
    "leaf_size": [1, 3, 5, 12],
}
svc_param_grid = {
    "kernel": ["rbf"],
    "gamma": [0.001, 0.01, 0.1],
    "C": [0.1, 1, 10, 50, 100],
}
gbc_param_grid = {
    "learning_rate": [0.05, 0.1, 0.2],
    "min_samples_split": [2, 3, 10],
    "min_samples_leaf": [1, 3, 10],
}
models2=[KNeighborsClassifier(),SVC(),GradientBoostingClassifier()]
param_grid=[knn_param_grid,svc_param_grid,gbc_param_grid]
for model,param in zip(models2,param_grid):
  grid_search=GridSearchCV(model,param,cv=5)
  grid_search.fit(X_train_lda,y_train)
  best_model=grid_search.best_estimator_

  y_pred=best_model.predict(X_test_lda)
  print(model,"-",end="")
  print(classification_report(y_test,y_pred))
  print(confusion_matrix(y_test,y_pred))
  print('Accuracy:',accuracy_score(y_test,y_pred))

# %%
from sklearn.model_selection import GridSearchCV
ada_param_grid = {"n_estimators": [50, 100, 200],
                  "learning_rate": [0.01, 0.1, 1.0],
                  "algorithm": ["SAMME", "SAMME.R"]
                  }

ext_param_grid = {"n_estimators": [50, 100, 200],
                  "max_depth": [1, 3,5],
                  "min_samples_split": [2, 5, 10],
                  "min_samples_leaf": [1, 5,10],
                  "criterion": ["gini", "entropy"],
                  "bootstrap": [True, False],
                  "max_features": [None, "sqrt", "log2"]
                  }
bag_param_grid = {"n_estimators": [50, 100, 200],
                  "max_samples": [0.5, 0.8, 1.0],
                 "max_features":[0.5,0.8,1.0],
                  "bootstrap": [True, False],
                  "bootstrap_features": [True, False]


                  }

models3=[AdaBoostClassifier(),ExtraTreesClassifier(),BaggingClassifier()]
param_grid=[ada_param_grid,ext_param_grid,bag_param_grid]

for model,param in zip(models3,param_grid):

  grid_search=GridSearchCV(model,param,cv=5)

  grid_search.fit(X_train_lda,y_train)
  best_model=grid_search.best_estimator_

  y_pred=best_model.predict(X_test_lda)

  print(model,"-",end="")
  print(classification_report(y_test,y_pred))
  print(confusion_matrix(y_test,y_pred))
  print('Accuracy:',accuracy_score(y_test,y_pred))
# Out:
# AdaBoostClassifier() -              precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98       105
#            1       0.93      0.99      0.96        91
#            2       0.89      0.92      0.90        92
#            3       0.96      0.91      0.94       112
#
#     accuracy                           0.94       400
#    macro avg       0.94      0.95      0.94       400
# weighted avg       0.95      0.94      0.95       400
#
# [[101   4   0   0]
#  [  0  90   1   0]
#  [  0   3  85   4]
#  [  0   0  10 102]]
# Accuracy: 0.945
# ExtraTreesClassifier() -              precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       105
#            1       0.97      0.97      0.97        91
#            2       0.91      0.96      0.93        92
#            3       0.96      0.94      0.95       112
#
#     accuracy                           0.96       400
#    macro avg       0.96      0.96      0.96       400
# ...

# %%
param_grid_xgb={


'max_depth':[	3, 5, 7, 9],
'learning_rate':[	0.01, 0.1, 0.5, 1.0],
'n_estimators':[	10, 50, 100, 200],
'gamma':[0, 0.1, 0.5, 1.0],
'subsample':[0.5, 0.7, 0.9, 1.0]
}
param_grid_gnb= {
    'var_smoothing': [1e-9, 1e-8, 1e-7, 1e-6, 1e-5],
    'priors': [None, [0.3, 0.4, 0.3], [0.2, 0.5, 0.3], [0.1, 0.6, 0.3]]
}

model4=[XGBClassifier(),GaussianNB()]
param_grid=[param_grid_xgb,param_grid_gnb]

for model,param in zip(model4,param_grid):

  grid_search=GridSearchCV(model,param,cv=5)
  grid_search.fit(X_train_lda,y_train)
  best_model=grid_search.best_estimator_


  y_pred=best_model.predict(X_test_lda)
  print(model,"-",end="")
  print(classification_report(y_test,y_pred))
  print(confusion_matrix(y_test,y_pred))
  print('Accuracy:',accuracy_score(y_test,y_pred))
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) -              precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99       105
#            1       0.95      0.97      0.96        91
# ...

# %% [markdown]
# **FEATURE SELECTION**

# %% [markdown]
# *** Before outliers detection***

# %% [markdown]
# **chi_2 for categorical feature selection**

# %%
x=data[["bluetooth","has_3g","has_4g","wifi","touch_screen","dual_sim"]]
y=data["price_range"]
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

chi_2=chi2(x,y)

chi_val=pd.Series(chi_2[0],index=x.columns)
chi_val.sort_values(ascending=False,inplace=True)
chi_val.plot(kind="bar")
plt.show()

# %%
p_val=pd.Series(chi_2[1],index=x.columns)
p_val.sort_values(ascending=False,inplace=True)
p_val.plot.bar()
plt.show()

# %% [markdown]
# **ANOVA F-value method**

# %%
from sklearn.feature_selection import SelectKBest,f_classif

import matplotlib.pyplot as plt

X=data[['battery_power',  'clock_speed',
       'front_camera_mpixels', 'int_memory', 'm_dep', 'mobile_wt',
       'n_cores', 'pc', 'px_height', 'px_width', 'ram', 'sc_h', 'sc_w',
       'talk_time']]
Y=data["price_range"]
fs=SelectKBest(f_classif,k='all')
fs.fit(X,Y)
ff=fs.get_support().sum()
print(ff)




print(fs.scores_)
val=pd.Series(fs.scores_,index=X.columns)
val.sort_values(ascending=False,inplace=True)
val.plot.bar()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   # that has no feature names.
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_tags.py:354: FutureWarning: The SelectKBest or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
# ...

# %% [markdown]
# **Lasso for numerical feature selection**

# %%
# Create LASSO model
from sklearn.linear_model import Lasso

lasso = Lasso(alpha=0.1)

# Fit LASSO model
lasso.fit(X, Y)

# Get coefficients
coefficients = lasso.coef_

# Print coefficients
for i,j in zip(X,coefficients):
    print(i,":",j)
# Out:
# battery_power : 0.0005102195792841492
# clock_speed : -0.0
# front_camera_mpixels : 0.0
# int_memory : 0.0005578031646947744
# m_dep : -0.0
# mobile_wt : -0.000808005498460973
# n_cores : 0.0
# pc : 0.0
# px_height : 0.0002752647865072588
# px_width : 0.00027898446544321264
# ram : 0.0009469472945827518
# sc_h : 0.0
# sc_w : 0.0
# talk_time : 0.0

# %% [markdown]
# **outliers detection**

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your data is in a pandas DataFrame called 'df'
# Replace 'df' with the actual name of your DataFrame

# 1. Visualizing outliers using box plots
# Box plots are a great way to visually identify potential outliers in your dataset
for column in data.columns:
    if pd.api.types.is_numeric_dtype(data[column]):
        plt.figure()  # Create a new figure for each plot
        sns.boxplot(x=data[column])
        plt.title(f'Box plot of {column}')
        plt.show()

# 2. Identifying outliers using the IQR method
def detect_outliers_iqr(df, col):
    if pd.api.types.is_numeric_dtype(df[col]):
        Q1 = np.percentile(df[col], 25)
        Q3 = np.percentile(df[col], 75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
        return outliers
    else:
        return None

outliers_all_cols = {}
for col in data.columns:
    outliers_all_cols[col] = detect_outliers_iqr(data, col)

for col, outliers in outliers_all_cols.items():
    print(f"Outliers in column {col}:")
    if outliers is not None:
        print(outliers)
    else:
        print("Column is not numeric.")
    print()

# 3. Identifying outliers using the Z-score method
# Calculate Z-scores for all numerical columns
from scipy import stats
df_zscore = data.select_dtypes(include=np.number).apply(stats.zscore)

# Identify outliers based on a Z-score threshold (e.g., 3)
outliers_zscore = data[(np.abs(df_zscore) > 3).any(axis=1)]
print("Outliers based on Z-score:")
print(outliers_zscore)
# Out:
# ...
# Outliers in column battery_power:
# Empty DataFrame
# Columns: [battery_power, bluetooth, clock_speed, dual_sim, front_camera_mpixels, has_4g, int_memory, m_dep, mobile_wt, n_cores, pc, px_height, px_width, ram, sc_h, sc_w, talk_time, has_3g, touch_screen, wifi, price_range]
# Index: []
#
# [0 rows x 21 columns]
#
# Outliers in column bluetooth:
# Empty DataFrame
# Columns: [battery_power, bluetooth, clock_speed, dual_sim, front_camera_mpixels, has_4g, int_memory, m_dep, mobile_wt, n_cores, pc, px_height, px_width, ram, sc_h, sc_w, talk_time, has_3g, touch_screen, wifi, price_range]
# Index: []
#
# [0 rows x 21 columns]
#
# Outliers in column clock_speed:
# Empty DataFrame
# Columns: [battery_power, bluetooth, clock_speed, dual_sim, front_camera_mpixels, has_4g, int_memory, m_dep, mobile_wt, n_cores, pc, px_height, px_width, ram, sc_h, sc_w, talk_time, has_3g, touch_screen, wifi, price_range]
# Index: []
#
# [0 rows x 21 columns]
#
# Outliers in column dual_sim:
# Empty DataFrame
# ...

# %% [markdown]
# **Removing outliers**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data1=data

# Define a function to detect outliers using IQR method
for col in data1.columns:
    Q1 = np.percentile(data1[col], 25)
    Q3 = np.percentile(data1[col], 75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    data1 = data1[~((data1[col] < lower_bound) | (data1[col] > upper_bound))]

# %%
data1.to_csv("prediction.csv",index=False)

# %%
data1.head()
# Out:
#    battery_power  bluetooth  clock_speed  dual_sim  front_camera_mpixels  \
# 1           1021          1          0.5         1                     0
# 2            563          1          0.5         1                     2
# 3            615          1          2.5         0                     0
# 4           1821          1          1.2         0                    13
# 5           1859          0          0.5         1                     3
#
#    has_4g  int_memory  m_dep  mobile_wt  n_cores  ...  px_height  px_width  \
# 1       1          53    0.7        136        3  ...        905      1988
# 2       1          41    0.9        145        5  ...       1263      1716
# 3       0          10    0.8        131        6  ...       1216      1786
# 4       1          44    0.6        141        2  ...       1208      1212
# 5       0          22    0.7        164        1  ...       1004      1654
#
#     ram  sc_h  sc_w  talk_time  has_3g  touch_screen  wifi  price_range
# ...

# %% [markdown]
# **After outliers remove**

# %% [markdown]
# ***categorical valued  features selection***

# %% [markdown]
# **chi_2 test**

# %%
x=data1[["bluetooth","has_3g","has_4g","wifi","touch_screen","dual_sim"]]
y=data1["price_range"]
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

chi_2=chi2(x,y)

chi_val=pd.Series(chi_2[0],index=x.columns)
chi_val.sort_values(ascending=False,inplace=True)
chi_val.plot(kind="bar")
plt.show()



p_val=pd.Series(chi_2[1],index=x.columns)
p_val.sort_values(ascending=False,inplace=True)
p_val.plot.bar()
plt.show()

# %% [markdown]
# **ANOVA method numerical valued feature selection**

# %%
from sklearn.feature_selection import SelectKBest,f_classif

import matplotlib.pyplot as plt

X=data1[['battery_power',  'clock_speed',
       'front_camera_mpixels', 'int_memory', 'm_dep', 'mobile_wt',
       'n_cores', 'pc', 'px_height', 'px_width', 'ram', 'sc_h', 'sc_w',
       'talk_time']]
Y=data1["price_range"]
fs=SelectKBest(f_classif,k='all')
fs.fit(X,Y)
ff=fs.get_support().sum()
print(ff)




print(fs.scores_)
val=pd.Series(fs.scores_,index=X.columns)
val.sort_values(ascending=False,inplace=True)
val.plot.bar()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   # that has no feature names.
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_tags.py:354: FutureWarning: The SelectKBest or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
# ...

# %% [markdown]
# **LASSO method for numeriacl feature selection**

# %%
# Create LASSO model
from sklearn.linear_model import Lasso

lasso = Lasso(alpha=0.1)

# Fit LASSO model
lasso.fit(X, Y)

# Get coefficients
coefficients = lasso.coef_

# Print coefficients
for i,j in zip(X,coefficients):
    print(i,":",j)
# Out:
# battery_power : 0.0005097348338867897
# clock_speed : -0.0
# front_camera_mpixels : 0.0
# int_memory : 0.0005308930778880174
# m_dep : -0.0
# mobile_wt : -0.0008553353757232557
# n_cores : 0.0
# pc : -0.0
# px_height : 0.0002836217077695272
# px_width : 0.00027364007206168617
# ram : 0.0009472962532074057
# sc_h : 0.0
# sc_w : -0.0
# talk_time : 0.0

# %%
plt.figure(figsize=(10, 6))
plt.barh(range(len(coefficients)), coefficients, align='center')
plt.yticks(np.arange(len(coefficients)), ['battery_power',  'clock_speed',
       'front_camera_mpixels', 'int_memory', 'm_dep', 'mobile_wt',
       'n_cores', 'pc', 'px_height', 'px_width', 'ram', 'sc_h', 'sc_w',
       'talk_time']) # Changed from tuple to list
plt.xlabel('Lasso Coefficients')
plt.title('Feature Importance based on Lasso Regression')
plt.show()

# %% [markdown]
# **soo....**
# ***the imp attributes are: in numerical ***
#
# 1)Battery_power
# 2)int_memory
# 3)mobile_wt
# 4)px_height
# 5)px_width
# 6)Ram

# %% [markdown]
# **the imp attributes in categorial:**
# 1)touch_screen
# 2)four_4g
# 3)bluetooth
# 4)dual_sim
# 5)wifi

# %%
x=data1.drop(columns=['price_range',
'has_3g',
'n_cores',
'sc_h',
'sc_w',
'talk_time',
'm_dep',
'pc',
'front_camera_mpixels',
'clock_speed'])
y=data1['price_range']

# %%
y
# Out:
# 1       2
# 2       2
# 3       2
# 4       1
# 5       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 1506, dtype: int64

# %%
x
# Out:
#       battery_power  bluetooth  dual_sim  has_4g  int_memory  mobile_wt  \
# 1              1021          1         1       1          53        136
# 2               563          1         1       1          41        145
# 3               615          1         0       0          10        131
# 4              1821          1         0       1          44        141
# 5              1859          0         1       0          22        164
# ...             ...        ...       ...     ...         ...        ...
# 1995            794          1         1       1           2        106
# 1996           1965          1         1       0          39        187
# 1997           1911          0         1       1          36        108
# 1998           1512          0         0       1          46        145
# 1999            510          1         1       1          45        168
#
#       px_height  px_width   ram  touch_screen  wifi
# ...

# %%
data2=data1
u=data2.drop(columns=[
'has_3g',

'n_cores',
'sc_h',
'sc_w',
'talk_time',
'm_dep',
'pc',
'front_camera_mpixels',
'clock_speed'])

plt.figure(figsize=(15,10))
corr_matrix = u.corr()
sns.heatmap(corr_matrix,cmap="coolwarm", annot=True, fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# **nomalizing data And model training**

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
# !pip install xgboost
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier,ExtraTreesClassifier,BaggingClassifier,StackingClassifier
from sklearn.model_selection import KFold,cross_val_score,cross_val_predict
from sklearn.model_selection import GridSearchCV
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

scaler = StandardScaler()

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

X_train=scaler.fit_transform(x_train)
X_test=scaler.transform(x_test)

models=[LogisticRegression(),RandomForestClassifier(),KNeighborsClassifier(),SVC(),GaussianNB(),DecisionTreeClassifier(),AdaBoostClassifier(),GradientBoostingClassifier(),ExtraTreesClassifier(),BaggingClassifier(),XGBClassifier()]
for model in models:
  model.fit(X_train,y_train)
  y_pred=model.predict(X_test)


  print(model,"-",end="")
  print('Accuracy:',accuracy_score(y_test,y_pred))
  print(classification_report(y_test,y_pred))
  print(confusion_matrix(y_test,y_pred))
  print("------------------------------------------------------------------")
# Out:
# ...
# LogisticRegression() -Accuracy: 0.9668874172185431
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97        88
#            1       0.93      0.96      0.94        71
#            2       0.96      0.97      0.96        66
#            3       1.00      0.97      0.99        77
#
#     accuracy                           0.97       302
#    macro avg       0.97      0.97      0.97       302
# weighted avg       0.97      0.97      0.97       302
#
# [[85  3  0  0]
#  [ 2 68  1  0]
#  [ 0  2 64  0]
#  [ 0  0  2 75]]
# ------------------------------------------------------------------
# RandomForestClassifier() -Accuracy: 0.9039735099337748
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91        88
#            1       0.82      0.83      0.83        71
#            2       0.91      0.89      0.90        66
#            3       1.00      0.95      0.97        77
#
# ...

# %%
# Out:
# array([[ 0.45260205, -0.96249675, -1.01506361, ..., -0.61299193,
#          0.98189151, -0.99337741],
#        [ 0.47293705,  1.03896454, -1.01506361, ...,  0.81141966,
#         -1.01844246,  1.00666674],
#        [ 0.73503264, -0.96249675,  0.98515994, ...,  1.70156014,
#         -1.01844246, -0.99337741],
#        ...,
#        [-0.1868208 , -0.96249675, -1.01506361, ...,  0.30423573,
#          0.98189151,  1.00666674],
#        [ 0.78248098,  1.03896454, -1.01506361, ...,  0.31451017,
#         -1.01844246, -0.99337741],
#        [ 1.13043546,  1.03896454,  0.98515994, ..., -0.23190345,
#          0.98189151, -0.99337741]])

# %% [markdown]
# **normalized data ,lda fitting,model training**

# %%
lda= LinearDiscriminantAnalysis(n_components=3)

X_train_lda=lda.fit_transform(X_train,y_train)
X_test_lda=lda.transform(X_test)

models=[LogisticRegression(),RandomForestClassifier(),KNeighborsClassifier(),SVC(),GaussianNB(),DecisionTreeClassifier(),AdaBoostClassifier(),GradientBoostingClassifier(),ExtraTreesClassifier(),BaggingClassifier(),XGBClassifier()]
for model in models:
  model.fit(X_train_lda,y_train)
  y_pred_lda=model.predict(X_test_lda)

  print(model,"-",end="")
  print('Accuracy:',accuracy_score(y_test,y_pred_lda))
  print(classification_report(y_test,y_pred_lda))
  print(confusion_matrix(y_test,y_pred_lda))
  print("------------------------------------------------------------------")
# Out:
# LogisticRegression() -Accuracy: 0.9735099337748344
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97        88
#            1       0.93      0.96      0.94        71
#            2       1.00      0.95      0.98        66
#            3       1.00      1.00      1.00        77
#
#     accuracy                           0.97       302
#    macro avg       0.97      0.97      0.97       302
# weighted avg       0.97      0.97      0.97       302
#
# [[86  2  0  0]
#  [ 3 68  0  0]
#  [ 0  3 63  0]
#  [ 0  0  0 77]]
# ------------------------------------------------------------------
# RandomForestClassifier() -Accuracy: 0.9668874172185431
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97        88
#            1       0.93      0.94      0.94        71
#            2       0.97      0.95      0.96        66
#            3       1.00      0.99      0.99        77
#
# ...

# %% [markdown]
# **normalized data,lda fitting,k-fold(models training)**

# %%
for model in models:
  model.fit(X_train_lda,y_train)
  kf = KFold(n_splits=10, shuffle=True, random_state=42)

  scores = cross_val_score(model, X_train_lda, y_train, cv=kf)
  print(model,"-",end="")
  print('score:',scores.mean()*100)

  y_pred_lda=cross_val_predict(model,X_test_lda,y_test,cv=kf)
  print(model,"-",end="")
  print('Accuracy:',accuracy_score(y_test,y_pred_lda)*100)
  print(classification_report(y_test,y_pred_lda))
  print(confusion_matrix(y_test,y_pred_lda))
  print("------------------------------------------------------------------")
# Out:
# LogisticRegression() -score: 96.76101928374656
# LogisticRegression() -Accuracy: 96.68874172185431
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97        88
#            1       0.94      0.92      0.93        71
#            2       0.96      0.97      0.96        66
#            3       1.00      1.00      1.00        77
#
#     accuracy                           0.97       302
#    macro avg       0.97      0.97      0.97       302
# weighted avg       0.97      0.97      0.97       302
#
# [[86  2  0  0]
#  [ 3 65  3  0]
#  [ 0  2 64  0]
#  [ 0  0  0 77]]
# ------------------------------------------------------------------
# RandomForestClassifier() -score: 95.4297520661157
# RandomForestClassifier() -Accuracy: 95.69536423841059
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97        88
#            1       0.91      0.94      0.92        71
# ...

# %% [markdown]
# **normalized data,lda fitting,gridsearchcv(models training)**

# %%
param_grid_rf = {
    'n_estimators': [100, 200, 300],  # number of trees
    'max_depth': [None, 5, 10],  # maximum depth of each tree
    'min_samples_split': [2, 5, 10]  # minimum samples required to split an internal node
}

param_grid1_dt = {
    'max_depth': [None, 5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 5, 10],
    'criterion': ['gini', 'entropy']
}
param_grid2_lr = {
    'C': [0.001, 0.01, 0.1, 1, 10],  # Inverse of regularization strength
    'penalty': ['l1', 'l2'],         # Regularization type
    'solver': ['liblinear', 'saga'], # Optimization algorithm
    'max_iter': [100, 200,300]
}
import time
models1=[RandomForestClassifier(),DecisionTreeClassifier(),LogisticRegression()]
param_grid=[param_grid_rf,param_grid1_dt,param_grid2_lr]
for model,param in zip(models1,param_grid):
  grid_search=GridSearchCV(model,param,cv=5)
  start_time=time.time()
  grid_search.fit(X_train_lda,y_train)
  best_model=grid_search.best_estimator_
  y_pred=best_model.predict(X_test_lda)
  end_time=time.time()
  print(model,"-",end="")

  print(classification_report(y_test,y_pred))
  print(confusion_matrix(y_test,y_pred))
  print('Accuracy:',accuracy_score(y_test,y_pred))
  print(end_time-start_time)
# Out:
# RandomForestClassifier() -              precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97        88
#            1       0.93      0.94      0.94        71
#            2       1.00      0.95      0.98        66
#            3       1.00      1.00      1.00        77
#
#     accuracy                           0.97       302
#    macro avg       0.97      0.97      0.97       302
# weighted avg       0.97      0.97      0.97       302
#
# [[86  2  0  0]
#  [ 4 67  0  0]
#  [ 0  3 63  0]
#  [ 0  0  0 77]]
# Accuracy: 0.9701986754966887
# 76.58890652656555
# DecisionTreeClassifier() -              precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97        88
#            1       0.96      0.93      0.94        71
#            2       0.96      0.98      0.97        66
#            3       1.00      0.99      0.99        77
#
#     accuracy                           0.97       302
# ...

# %%
import numpy as np
knn_param_grid = {
    "n_neighbors": np.linspace(2, 20, 12, dtype=int).tolist(),
    "weights": ["uniform", "distance"],
    "metric": ["euclidean", "manhattan", "minkowski"],
    "leaf_size": [1, 3, 5, 12],
}
svc_param_grid = {
    "kernel": ["rbf"],
    "gamma": [0.001, 0.01, 0.1],
    "C": [0.1, 1, 10, 50, 100],
}
gbc_param_grid = {
    "learning_rate": [0.05, 0.1, 0.2],
    "min_samples_split": [2, 3, 10],
    "min_samples_leaf": [1, 3, 10],
}
import time
models2=[KNeighborsClassifier(),SVC(),GradientBoostingClassifier()]
param_grid=[knn_param_grid,svc_param_grid,gbc_param_grid]
for model,param in zip(models2,param_grid):
  grid_search=GridSearchCV(model,param,cv=5)
  start_time=time.time()
  grid_search.fit(X_train_lda,y_train)
  best_model=grid_search.best_estimator_

  y_pred=best_model.predict(X_test_lda)
  end_time=time.time()
  print(model,"-",end="")
  print(classification_report(y_test,y_pred))
  print(confusion_matrix(y_test,y_pred))
  print('Accuracy:',accuracy_score(y_test,y_pred))
  print(end_time-start_time)
# Out:
# KNeighborsClassifier() -              precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        88
#            1       0.94      0.96      0.95        71
#            2       0.98      0.95      0.97        66
#            3       1.00      0.99      0.99        77
#
#     accuracy                           0.97       302
#    macro avg       0.97      0.97      0.97       302
# weighted avg       0.97      0.97      0.97       302
#
# [[87  1  0  0]
#  [ 3 68  0  0]
#  [ 0  3 63  0]
#  [ 0  0  1 76]]
# Accuracy: 0.9735099337748344
# 20.03781509399414
# SVC() -              precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        88
#            1       0.94      0.96      0.95        71
#            2       0.98      0.95      0.97        66
#            3       1.00      0.99      0.99        77
#
#     accuracy                           0.97       302
# ...

# %%
from sklearn.model_selection import GridSearchCV
ada_param_grid = {"n_estimators": [50, 100, 200],
                  "learning_rate": [0.01, 0.1, 1.0],
                  "algorithm": ["SAMME", "SAMME.R"]
                  }

ext_param_grid = {"n_estimators": [50, 100, 200],
                  "max_depth": [1, 3,5],
                  "min_samples_split": [2, 5, 10],
                  "min_samples_leaf": [1, 5,10],
                  "criterion": ["gini", "entropy"],
                  "bootstrap": [True, False],
                  "max_features": [None, "sqrt", "log2"]
                  }
bag_param_grid = {"n_estimators": [50, 100, 200],
                  "max_samples": [0.5, 0.8, 1.0],
                 "max_features":[0.5,0.8,1.0],
                  "bootstrap": [True, False],
                  "bootstrap_features": [True, False]


                  }
import time
models3=[AdaBoostClassifier(),ExtraTreesClassifier(),BaggingClassifier()]
param_grid=[ada_param_grid,ext_param_grid,bag_param_grid]

for model,param in zip(models3,param_grid):

  grid_search=GridSearchCV(model,param,cv=5)
  start_time=time.time()
  grid_search.fit(X_train_lda,y_train)
  best_model=grid_search.best_estimator_

  y_pred=best_model.predict(X_test_lda)
  end_time=time.time()
  print(model,"-",end="")
  print(classification_report(y_test,y_pred))
  print(confusion_matrix(y_test,y_pred))
  print('Accuracy:',accuracy_score(y_test,y_pred))
  print(end_time-start_time)
# Out:
# AdaBoostClassifier() -              precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98        88
#            1       0.93      0.99      0.96        71
#            2       0.98      0.94      0.96        66
#            3       0.99      0.99      0.99        77
#
#     accuracy                           0.97       302
#    macro avg       0.97      0.97      0.97       302
# weighted avg       0.97      0.97      0.97       302
#
# [[86  2  0  0]
#  [ 1 70  0  0]
#  [ 0  3 62  1]
#  [ 0  0  1 76]]
# Accuracy: 0.9735099337748344
# 33.178330183029175
# ExtraTreesClassifier() -              precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96        88
#            1       0.93      0.92      0.92        71
#            2       0.98      0.94      0.96        66
#            3       1.00      0.99      0.99        77
#
#     accuracy                           0.96       302
# ...

# %%
param_grid_xgb={


'max_depth':[	3, 5, 7, 9],
'learning_rate':[	0.01, 0.1, 0.5, 1.0],
'n_estimators':[	10, 50, 100, 200],
'gamma':[0, 0.1, 0.5, 1.0],
'subsample':[0.5, 0.7, 0.9, 1.0]
}
param_grid_gnb= {
    'var_smoothing': [1e-9, 1e-8, 1e-7, 1e-6, 1e-5],
    'priors': [None, [0.3, 0.4, 0.3], [0.2, 0.5, 0.3], [0.1, 0.6, 0.3]]
}
import time
model4=[XGBClassifier(),GaussianNB()]
param_grid=[param_grid_xgb,param_grid_gnb]

for model,param in zip(model4,param_grid):

  grid_search=GridSearchCV(model,param,cv=5)
  start_time=time.time()
  grid_search.fit(X_train_lda,y_train)
  best_model=grid_search.best_estimator_


  y_pred=best_model.predict(X_test_lda)
  end_time=time.time()
  print(model,"-",end="")
  print(classification_report(y_test,y_pred))
  print(confusion_matrix(y_test,y_pred))
  print('Accuracy:',accuracy_score(y_test,y_pred))
  print(end_time-start_time)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...) -              precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97        88
#            1       0.94      0.93      0.94        71
# ...

# %%
from sklearn.metrics import roc_curve, auc


from sklearn.preprocessing import label_binarize
from sklearn.metrics import RocCurveDisplay






svc_param_grid = {
    "kernel": ["rbf"],
    "gamma": [0.001, 0.01, 0.1],
    "C": [0.1, 1, 10, 50, 100],
}


import time
models1=[SVC(),DecisionTreeClassifier()]
param_grid=[svc_param_grid,param_grid1_dt]


d_ata=[[1137	      ,          1	  ,   0   ,    	0     , 	7      ,   196 ,   942  ,   1179  , 3616  , 1        ,     1	]]
n_ormal=scaler.transform(d_ata)
l_da=lda.transform(n_ormal) # Reshape the 1D list into a 2D array with one row and multiple columns.



for model,param in zip(models1,param_grid):
  grid_search=GridSearchCV(model,param,cv=5)
  start_time=time.time()
  grid_search.fit(X_train_lda,y_train)
  best_model=grid_search.best_estimator_
  y_pred=best_model.predict(X_test_lda)



  p_rediction=best_model.predict(l_da)
  print(p_rediction,"this is the prediction")


  end_time=time.time()
  print(model,"-",end="")

  print(classification_report(y_test,y_pred))
  print(confusion_matrix(y_test,y_pred))
  print('Accuracy:',accuracy_score(y_test,y_pred))
  print(end_time-start_time)


  print('Time taken:', end_time - start_time)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [3] this is the prediction
# SVC() -              precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        88
#            1       0.94      0.96      0.95        71
#            2       0.98      0.95      0.97        66
#            3       1.00      0.99      0.99        77
#
#     accuracy                           0.97       302
#    macro avg       0.97      0.97      0.97       302
# weighted avg       0.97      0.97      0.97       302
#
# [[87  1  0  0]
#  [ 3 68  0  0]
#  [ 0  3 63  0]
#  [ 0  0  1 76]]
# Accuracy: 0.9735099337748344
# 3.144479513168335
# Time taken: 3.144479513168335
# [3] this is the prediction
# DecisionTreeClassifier() -              precision    recall  f1-score   support
#
# ...

# %%
d_ata=[[1137	      ,          1	  ,   0   ,    	0     , 	7      ,   196 ,   942  ,   1179  , 3616  , 1        ,     1	]]
n_ormal=scaler.transform(d_ata)
l_da=lda.transform(n_ormal)
pred=best_model.predict(l_da)
print(pred)
# Out:
# [3]
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
print(pred)
# Out:
# [3]

# %%
from joblib import dump

# Save the model
dump(best_model, 'model.joblib')
dump(scaler, 'scaler.joblib')
dump(lda, 'lda.joblib')
print("ok")
# Out:
# ok

# %%
import google.colab as colab
colab.files.download('model.joblib')
colab.files.download('scaler.joblib')
colab.files.download('lda.joblib')

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import label_binarize
import time

# Assume you already have X_train_lda, X_test_lda, y_train, y_test from your dataset

# Binarize the output (for multiclass problems)
n_classes = len(np.unique(y_train))  # Number of classes
y_train_bin = label_binarize(y_train, classes=np.arange(n_classes))
y_test_bin = label_binarize(y_test, classes=np.arange(n_classes))

svc_param_grid = {
    "kernel": ["rbf"],
    "gamma": [0.001, 0.01, 0.1],
    "C": [0.1, 1, 10, 50, 100],
}

param_grid1_dt = {
    'max_depth': [None, 5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 5, 10],
    'criterion': ['gini', 'entropy']
}

models1 = [SVC(probability=True), DecisionTreeClassifier()]
param_grid = [svc_param_grid, param_grid1_dt]

# Loop through each model
for model, param in zip(models1, param_grid):
    # Perform grid search
    grid_search = GridSearchCV(model, param, cv=5)
    start_time = time.time()
    grid_search.fit(X_train_lda, y_train)
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(X_test_lda)
    end_time = time.time()

    # Print classification metrics
    print(f"Model: {type(best_model).__name__}")
    print("Classification Report:\n", classification_report(y_test, y_pred))
    print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
    print('Accuracy:', accuracy_score(y_test, y_pred))
    print(f"Time Taken: {end_time - start_time:.2f} seconds\n")

    # Plot Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(6, 5))
    plt.matshow(cm, cmap='coolwarm', fignum=1)
    plt.title(f'Confusion Matrix - {type(best_model).__name__}', pad=20)
    plt.colorbar()
    plt.xlabel('Predicted Class', fontsize=12)
    plt.ylabel('True Class', fontsize=12)

    # Annotate confusion matrix
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, str(cm[i, j]), va='center', ha='center', fontsize=14)

    plt.show()  # Show the confusion matrix for this model

    # ROC Curve computation (One-vs-Rest for multiclass)
    if hasattr(best_model, "predict_proba"):
        y_prob = best_model.predict_proba(X_test_lda)  # Get probabilities for each class
    else:
        y_prob = best_model.decision_function(X_test_lda)  # Decision function for SVC

    # Initialize figure for ROC curve
    plt.figure(figsize=(12, 8))
    plt.title('ROC Curve for Different Models', fontsize=16)

    # For each class, calculate the ROC curve
    for i in range(n_classes):
        fpr, tpr, _ = roc_curve(y_test_bin[:, i], y_prob[:, i])
        roc_auc = auc(fpr, tpr)

        # Plot ROC Curve for each class
        plt.plot(fpr, tpr, lw=2, label=f'Class {i} (AUC = {roc_auc:.2f})')

    # Plot ROC curve baseline
    plt.plot([0, 1], [0, 1], 'k--', lw=2, label='Chance Level')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate', fontsize=12)
    plt.ylabel('True Positive Rate', fontsize=12)
    plt.legend(loc="lower right", fontsize=10)
    plt.grid(True)

    plt.show()  # Show the ROC curve for this model
# Out:
# Model: SVC
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        88
#            1       0.94      0.96      0.95        71
#            2       0.98      0.95      0.97        66
#            3       1.00      0.99      0.99        77
#
#     accuracy                           0.97       302
#    macro avg       0.97      0.97      0.97       302
# weighted avg       0.97      0.97      0.97       302
#
# Confusion Matrix:
#  [[87  1  0  0]
#  [ 3 68  0  0]
#  [ 0  3 63  0]
#  [ 0  0  1 76]]
# Accuracy: 0.9735099337748344
# Time Taken: 7.31 seconds
# Model: DecisionTreeClassifier
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97        88
#            1       0.96      0.93      0.94        71
#            2       0.96      0.98      0.97        66
#            3       1.00      0.99      0.99        77
#
# ...

# %%
param_grid_rf = {
    'n_estimators': [100, 200, 300],  # number of trees
    'max_depth': [None, 5, 10],  # maximum depth of each tree
    'min_samples_split': [2, 5, 10]  # minimum samples required to split an internal node
}

param_grid1_dt = {
    'max_depth': [None, 5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 5, 10],
    'criterion': ['gini', 'entropy']
}
param_grid2_lr = {
    'C': [0.001, 0.01, 0.1, 1, 10],  # Inverse of regularization strength
    'penalty': ['l1', 'l2'],         # Regularization type
    'solver': ['liblinear', 'saga'], # Optimization algorithm
    'max_iter': [100, 200,300]
}

param_grid_xgb={


'max_depth':[	3, 5, 7, 9],
'learning_rate':[	0.01, 0.1, 0.5, 1.0],
'n_estimators':[	10, 50, 100, 200],
'gamma':[0, 0.1, 0.5, 1.0],
'subsample':[0.5, 0.7, 0.9, 1.0]
}
param_grid_gnb= {
    'var_smoothing': [1e-9, 1e-8, 1e-7, 1e-6, 1e-5],
    'priors': [None, [0.3, 0.4, 0.3], [0.2, 0.5, 0.3], [0.1, 0.6, 0.3]]
}





from sklearn.model_selection import GridSearchCV
ada_param_grid = {"n_estimators": [50, 100, 200],
                  "learning_rate": [0.01, 0.1, 1.0],
                  "algorithm": ["SAMME", "SAMME.R"]
                  }

ext_param_grid = {"n_estimators": [50, 100, 200],
                  "max_depth": [1, 3,5],
                  "min_samples_split": [2, 5, 10],
                  "min_samples_leaf": [1, 5,10],
                  "criterion": ["gini", "entropy"],
                  "bootstrap": [True, False],
                  "max_features": [None, "sqrt", "log2"]
                  }
bag_param_grid = {"n_estimators": [50, 100, 200],
                  "max_samples": [0.5, 0.8, 1.0],
                 "max_features":[0.5,0.8,1.0],
                  "bootstrap": [True, False],
                  "bootstrap_features": [True, False]


                  }



import numpy as np
knn_param_grid = {
    "n_neighbors": np.linspace(2, 20, 12, dtype=int).tolist(),
    "weights": ["uniform", "distance"],
    "metric": ["euclidean", "manhattan", "minkowski"],
    "leaf_size": [1, 3, 5, 12],
}
svc_param_grid = {
    "kernel": ["rbf"],
    "gamma": [0.001, 0.01, 0.1],
    "C": [0.1, 1, 10, 50, 100],
}
gbc_param_grid = {
    "learning_rate": [0.05, 0.1, 0.2],
    "min_samples_split": [2, 3, 10],
    "min_samples_leaf": [1, 3, 10],
}


import time
models1=[SVC(),DecisionTreeClassifier(),RandomForestClassifier(),LogisticRegression(),XGBClassifier(),GaussianNB(),AdaBoostClassifier(),ExtraTreesClassifier(),BaggingClassifier(),KNeighborsClassifier(),GradientBoostingClassifier()]
param_grid=[svc_param_grid,param_grid1_dt,param_grid_rf,param_grid2_lr,param_grid_xgb,param_grid_gnb,ada_param_grid,ext_param_grid,bag_param_grid,knn_param_grid,gbc_param_grid]
for model,param in zip(models1,param_grid):
  grid_search=GridSearchCV(model,param,cv=5)
  start_time=time.time()
  grid_search.fit(X_train_lda,y_train)
  best_model=grid_search.best_estimator_
  y_pred=best_model.predict(X_test_lda)
  end_time=time.time()
  print(model,"-",end="")

  print(classification_report(y_test,y_pred))
  print(confusion_matrix(y_test,y_pred))
  print('Accuracy:',accuracy_score(y_test,y_pred))
  print(end_time-start_time)
  print(model, "-")
  print(classification_report(y_test, y_pred))
  print(confusion_matrix(y_test, y_pred))
  print('Accuracy:', accuracy_score(y_test, y_pred))
  print('Time taken:', end_time - start_time)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.preprocessing import label_binarize

# Binarize the labels for ROC calculation
n_classes = len(np.unique(y_test))
y_test_bin = label_binarize(y_test, classes=np.unique(y_test))

models1 = [
    SVC(probability=True),  # Ensure SVC uses probability=True for predict_proba
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    LogisticRegression(),
    XGBClassifier(),
    GaussianNB(),
    AdaBoostClassifier(),
    ExtraTreesClassifier(),
    BaggingClassifier(),
    KNeighborsClassifier(),
    GradientBoostingClassifier()
]

param_grid = [
    svc_param_grid,
    param_grid1_dt,
    param_grid_rf,
    param_grid2_lr,
    param_grid_xgb,
    param_grid_gnb,
    ada_param_grid,
    ext_param_grid,
    bag_param_grid,
    knn_param_grid,
    gbc_param_grid
]

plt.figure(figsize=(10, 8))

# Iterate through models and parameter grids
for model, param in zip(models1, param_grid):
    grid_search = GridSearchCV(model, param, cv=5)
    start_time = time.time()
    grid_search.fit(X_train_lda, y_train)
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(X_test_lda)

    # Ensure the model can output probability predictions
    if hasattr(best_model, "predict_proba"):
        y_prob = best_model.predict_proba(X_test_lda)
    else:
        continue  # Skip models without probability estimation

    end_time = time.time()

    print(f"{model.__class__.__name__} -")
    print(classification_report(y_test, y_pred))
    print(confusion_matrix(y_test, y_pred))
    print('Accuracy:', accuracy_score(y_test, y_pred))
    print('Time taken:', end_time - start_time)

    # Compute ROC curve and ROC area for each class
    for i in range(n_classes):
        fpr, tpr, _ = roc_curve(y_test_bin[:, i], y_prob[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f'{model.__class__.__name__} Class {i} (AUC = {roc_auc:.2f})')

# Plot the ROC curve with diagonal reference line
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve for Multiclass')
plt.legend(loc='lower right')
plt.show()
# Out:
# SVC -
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        88
#            1       0.94      0.96      0.95        71
#            2       0.98      0.95      0.97        66
#            3       1.00      0.99      0.99        77
#
#     accuracy                           0.97       302
#    macro avg       0.97      0.97      0.97       302
# weighted avg       0.97      0.97      0.97       302
#
# [[87  1  0  0]
#  [ 3 68  0  0]
#  [ 0  3 63  0]
#  [ 0  0  1 76]]
# Accuracy: 0.9735099337748344
# Time taken: 8.39692497253418
# DecisionTreeClassifier -
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97        88
#            1       0.96      0.93      0.94        71
#            2       0.96      0.98      0.97        66
#            3       1.00      0.99      0.99        77
#
#     accuracy                           0.97       302
# ...
